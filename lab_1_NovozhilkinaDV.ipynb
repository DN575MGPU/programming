# %% [markdown]
# <a href="https://colab.research.google.com/github/DN575MGPU/programming/blob/main/lab_1_NovozhilkinaDV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Задание task_01_07.
#
# Выполнил: Новожилкина Д. В.
# Группа: ЦИБ-251


team = input("Введите название команды: ")

print(team, "- чемпион!")

print("Символов в названии команды:", len(team))


team_lowercase =  team.lower()

x = "п"
y = "а"

print("Буква \"п\" есть:", x in team)
print("Количество букв \"а\":", team.count(y))
# Out:
# Введите название команды: Спартак
# Спартак - чемпион!
# Символов в названии команды: 7
# Буква "п" есть: True
# Количество букв "а": 2
